# %%
import numpy as np

# %%
dados= np.random.exponential(20, size=1000)

# %%
sns.distplot(dados)
# Out:
# <AxesSubplot:>

# %%
escolhas = []
for i in range(100):
    escolhas.append(np.random.choice(dados, size=30).mean())

# %%
sns.distplot(escolhas)
# Out:
# <AxesSubplot:>

# %%
a = [1,2,1,5,8,7,4,55,45,32,6,495,32,65,5]

# %%
a
# Out:
# [1, 2, 1, 5, 8, 7, 4, 55, 45, 32, 6, 495, 32, 65, 5]

# %%
np.random.choice(a,6)
# Out:
# array([495, 495,  32,   7,   5,   4])

# %%
sns.distplot(dados)
# Out:
# <AxesSubplot:>

# %%
import scipy.stats as st

# %%
sns.distplot(st.zscore(dados))
# Out:
# <AxesSubplot:>

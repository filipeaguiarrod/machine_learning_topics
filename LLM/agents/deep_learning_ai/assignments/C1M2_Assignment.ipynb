# %% [markdown]
# ## Graded Lab: Reflection in a Research Agent
#
# In this graded lab, you’ll implement a simple **agentic workflow** designed to simulate reflective thinking in a writing task. This is one building block of a more complex research agent that will be constructed throughout the course.
#
# ### Objective
#
# Build a three-step workflow where an LLM writes an essay draft, critiques it, and rewrites it.
#
# * **Step 1 – Drafting:** Call the LLM to generate an initial draft of an essay based on a simple prompt.
# * **Step 2 – Reflection:** Reflect on the draft using a reasoning step. (Optionally, this can be done with a different model.)
# * **Step 3 – Revision:** Apply the feedback from the reflection to generate a revised version of the essay.

# %% [markdown]
# ---
# <a name='submission'></a>
#
# <h4 style="color:green; font-weight:bold;">TIPS FOR SUCCESSFUL GRADING OF YOUR ASSIGNMENT:</h4>
#
# * All cells are frozen except for the ones where you need to write your solution code or when explicitly mentioned you can interact with it.
#
# * In each exercise cell, look for comments `### START CODE HERE ###` and `### END CODE HERE ###`. These show you where to write the solution code. **Do not add or change any code that is outside these comments**.
#
# * You can add new cells to experiment but these will be omitted by the grader, so don't rely on newly created cells to host your solution code, use the provided places for this.
#
# * Avoid using global variables unless you absolutely have to. The grader tests your code in an isolated environment without running all cells from the top. As a result, global variables may be unavailable when scoring your submission. Global variables that are meant to be used will be defined in UPPERCASE.
#
# * To submit your notebook for grading, first save it by clicking the 💾 icon on the top left of the page and then click on the <span style="background-color: red; color: white; padding: 3px 5px; font-size: 16px; border-radius: 5px;">Submit assignment</span> button on the top right of the page.
# ---

# %% [markdown]
# Before interacting with the language models, we initialize the `aisuite` client. This setup loads environment variables (e.g., API keys) from a `.env` file to securely authenticate with backend services. The `ai.Client()` instance will be used to make all model calls throughout this workflow.

# %%
from dotenv import load_dotenv

load_dotenv()

import aisuite as ai

# Define the client. You can use this variable inside your graded functions!
CLIENT = ai.Client()

# %%
import unittests

# %% [markdown]
# ## Exercise 1: `generate_draft` Function
#
# **Objective**:
# Write a function called `generate_draft` that takes in a string topic and uses a language model to generate a complete draft essay.
#
# **Inputs**:
#
# * `topic` (str): The essay topic.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string representing the full draft of the essay.
#
# The setup for calling the LLM using the aisuite library is already provided. Focus on crafting the prompt content. You can reference this setup in later exercises to understand how to interact with the library effectively.

# %%
# GRADED FUNCTION: generate_draft

def generate_draft(topic: str, model: str = "openai:gpt-4o") -> str: 
    
    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f""" Create an essay for the topic: {topic} """ 

    ### END CODE HERE ###
    
    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %% [markdown]
# Run the following cell to check your code is working correctly:

# %%
# Test your code!
unittests.test_generate_draft(generate_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 2: `reflect_on_draft` Function
#
# **Objective**:
# Write a function called `reflect_on_draft` that takes a previously generated essay draft and uses a language model to provide constructive feedback.
#
# **Inputs**:
#
# * `draft` (str): The essay text to reflect on.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:o4-mini"`.
#
# **Output**:
#
# * A string with feedback in paragraph form.
#
# **Requirements**:
#
# * The feedback should be critical but constructive.
# * It should address issues such as structure, clarity, strength of argument, and writing style.
# * The function should send the draft to the model and return its response.
#
# You do **not** need to rewrite the essay at this step—just analyze and reflect on it.

# %%
# GRADED FUNCTION: reflect_on_draft

def reflect_on_draft(draft: str, model: str = "openai:o4-mini") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f""" Based on essay provided you should create and return a feedback in 
    parapraph form. 
    Consider following requirements at your feedback:
    - The feedback should be critical but constructive.
    - It should address issues such as structure, clarity, strength of argument, and writing style.
    - The function should send the draft to the model and return its response
    
    Essay:{draft}
    """

    ### END CODE HERE ###

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_reflect_on_draft(reflect_on_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 3: `revise_draft` Function
#
# **Objective**:
# Implement a function called `revise_draft` that improves a given essay draft based on feedback from a reflection step.
#
# **Inputs**:
#
# * `original_draft` (str): The initial version of the essay.
# * `reflection` (str): Constructive feedback or critique on the draft.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string containing the revised and improved essay.
#
# **Requirements**:
#
# * The revised draft should address the issues mentioned in the feedback.
# * It should improve clarity, coherence, argument strength, and overall flow.
# * The function should use the feedback to guide the revision, and return only the final revised essay.
#
# In this final exercise, you'll also need to manage the call to the LLM using the CLIENT, as you've practiced in previous exercises.

# %%
# GRADED FUNCTION: revise_draft

def revise_draft(original_draft: str, reflection: str, model: str = "openai:gpt-4o") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt =f"""Considering the draft of essay created: {original_draft}, and the
    feedback: {reflection} about it, rewrite new essay addressing appointments of in
    feedback"""

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )
    ### END CODE HERE ###

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_revise_draft(revise_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ### 🧪 Test the Reflective Writing Workflow
#
# Use the functions you implemented to simulate the complete writing workflow:
#
# 1. **Generate a draft** in response to the essay prompt.
# 2. **Reflect** on the draft to identify improvements.
# 3. **Revise** the draft using the feedback.
#
# Observe the outputs of each step. You do **not** need to modify the outputs — just verify that the workflow runs as expected and each component returns a valid string.

# %%
essay_prompt = "Should social media platforms be regulated by the government?"

# Agent 1 – Draft
draft = generate_draft(essay_prompt)
print("📝 Draft:\n")
print(draft)

# Agent 2 – Reflection
feedback = reflect_on_draft(draft)
print("\n🧠 Feedback:\n")
print(feedback)

# Agent 3 – Revision
revised = revise_draft(draft, feedback)
print("\n✍️ Revised:\n")
print(revised)
# Out:
# 📝 Draft:
#
# Title: The Role of Government in Regulating Social Media Platforms
#
# Introduction
#
# The advent of social media has revolutionized how people communicate, share information, and engage with global communities. However, the rapid evolution of these platforms has also unleashed complex societal challenges, including the spread of misinformation, violations of privacy, and the impact on mental health. These challenges have sparked debates on whether social media platforms should be regulated by the government. This essay delves into the arguments for and against governmental regulation, ultimately advocating for a balanced approach that safeguards public interest while respecting freedom of expression.
#
# Arguments for Government Regulation
#
# 1. **Curbing Misinformation**: One of the most compelling arguments for government intervention is the need to control the spread of misinformation and fake news. Social media platforms have been used to disseminate false information rapidly, influencing public opinion and, at times, undermining democratic processes. Government regulation could mandate stricter content verification standards and hold platforms accountable for the spread of harmful misinformation.
#
# 2. **Protecting Privacy**: Social media platforms collect vast amounts of personal data, often with little transparency about how it is used. Government regulation could ensure robust data protection laws that safeguard users' privacy rights. By enforcing stringent data handling and privacy practices, governments can protect citizens from data breaches and misuse.
#
# 3. **Addressing Harmful Content**: The prevalence of hate speech, cyberbullying, and other harmful content on social media is another significant concern. Government regulation can compel platforms to implement better mechanisms for identifying and removing such material. This can create safer online environments and protect vulnerable populations from online abuse.
#
# 4. **Promoting Competition and Innovation**: The dominance of a few major social media companies has raised concerns about monopolistic practices. Government oversight can ensure fair competition and prevent these giants from stifling innovation or exploiting their market position at the expense of consumers and smaller businesses.
#
# Arguments Against Government Regulation
#
# 1. **Freedom of Expression**: One of the most significant concerns regarding government regulation is the potential threat to freedom of speech. Overregulation might lead to censorship, where legitimate expression is suppressed, stifling diverse opinions and infringing on the public's right to information.
#
# 2. **Innovation Stifling**: Heavy-handed regulation can inhibit technological innovation and adaptability. Social media platforms need the flexibility to evolve and improve their services. Overbearing regulatory frameworks might delay the introduction of new features and restrict creativity in addressing emerging challenges.
#
# 3. **Implementation Challenges**: Enforcing regulations consistently across diverse platforms presents substantial logistical challenges. Governments may struggle to keep pace with the technology's rapid evolution, resulting in outdated or irrelevant regulations that fail to address the actual issues.
#
# 4. **Global Reach and Jurisdiction Issues**: Social media platforms transcend national boundaries, leading to jurisdictional complexities. What one country deems necessary regulation may be viewed as overreach by another, complicating international compliance and cooperation efforts.
#
# Finding the Balance: A Collaborative Approach
#
# Given these contrasting perspectives, finding the right balance in regulating social media platforms is crucial. A collaborative approach, involving governments, tech companies, civil society, and academicians, can help achieve this balance. Governments can establish baseline regulations focusing on critical areas like data privacy, platform accountability, and harmful content, allowing platforms to devise innovative compliance methods.
#
# Additionally, independent oversight bodies comprising diverse stakeholders can be established to monitor compliance and recommend adjustments in regulations. Such bodies can ensure regulations evolve with technology and societal needs, creating adaptive frameworks that protect public interest without stifling innovation or free speech.
#
# Conclusion
#
# The regulation of social media platforms by the government is a multifaceted issue that requires careful consideration of both the benefits and potential drawbacks. While regulation is essential in addressing pressing concerns like misinformation, privacy erosion, and harmful content, it must be implemented thoughtfully to avoid overreach and infringement on fundamental freedoms. A balanced, collaborative approach can help establish effective regulatory mechanisms that protect public welfare while nurturing the vibrant ecosystem of innovation and expression that social media platforms offer.
#
# 🧠 Feedback:
#
# Your essay offers a clear and balanced exploration of government regulation of social media, yet a few adjustments could make your argument more compelling. Structurally, the “for” and “against” sections are well organized, but they read slightly like itemized lists; weaving in concrete examples or brief case studies—for instance, referencing a specific misinformation campaign or data-privacy breach—would ground your points and improve flow. Transitions between paragraphs could also be smoother to guide the reader more naturally from one idea to the next, especially into your conclusion, which currently restates earlier claims rather than synthesizing them. In terms of clarity, some sentences are densely packed with abstract concepts; simplifying phrasing and breaking complex thoughts into shorter statements would sharpen your message. Your writing style is formal and appropriate, yet it leans heavily on passive constructions—shifting to a more active voice and varying sentence rhythm would increase reader engagement. Finally, while you rightly highlight tensions between free speech and regulation, bolstering these claims with a few scholarly or legal citations would heighten the essay’s authority. With these refinements—more vivid examples, smoother transitions, clearer phrasing, and added evidence—your balanced approach will carry even greater persuasive weight.
#
# ✍️ Revised:
#
# Title: The Role of Government in Regulating Social Media Platforms
#
# Introduction
#
# Social media platforms have become integral to global communication, shaping how people interact, share information, and form communities. However, their rapid growth has also introduced significant challenges, such as misinformation, privacy violations, and impacts on mental health. These challenges necessitate a discussion on the role of government in regulating these platforms. This essay examines both sides of the argument and advocates for a balanced approach that safeguards public interest while upholding freedom of expression.
#
# Arguments for Government Regulation
#
# 1. **Curbing Misinformation**: Social media platforms have been breeding grounds for misinformation and fake news. For instance, during recent elections, false narratives spread rapidly, potentially influencing public opinion and jeopardizing democratic processes. Government intervention is crucial to enforce content verification standards and hold platforms accountable for the dissemination of harmful misinformation.
#
# 2. **Protecting Privacy**: Social media platforms often collect vast amounts of personal data without clear transparency, as seen in notable data breaches like the Cambridge Analytica scandal. To protect privacy rights, government regulations are necessary to ensure robust data protection laws and enforce stringent data handling practices.
#
# 3. **Addressing Harmful Content**: The spread of hate speech and cyberbullying is prevalent on social media. For example, incidents of online harassment have shown the need for better content moderation. Government regulation can require platforms to identify and remove harmful content, creating safer online spaces.
#
# 4. **Promoting Competition and Innovation**: The dominance of major players stifles competition and innovation. Past instances show how monopolistic practices can hinder smaller enterprises. Through oversight, governments can foster fair competition, ensuring that new players have the opportunity to innovate and thrive.
#
# Arguments Against Government Regulation
#
# 1. **Freedom of Expression**: Government regulation risks infringing on freedom of speech. Historical censorship attempts have raised concerns about overreach, where legitimate discourse might be stifled, limiting diverse viewpoints and the free flow of information.
#
# 2. **Innovation Stifling**: Strict regulations may impede the creative evolution of social media platforms. Overbearing rules could delay the introduction of new features, as platforms struggle to comply with complex regulatory frameworks.
#
# 3. **Implementation Challenges**: Governments face difficulties in enforcing regulations efficiently. Social media evolves rapidly, and regulators may struggle to keep pace, resulting in outdated rules that fail to address current issues.
#
# 4. **Global Reach and Jurisdiction Issues**: Social media's international scope complicates regulation. Conflicting national laws can lead to jurisdictional challenges, as seen in differing privacy laws across countries, complicating compliance for global platforms.
#
# Finding the Balance: A Collaborative Approach
#
# To navigate these complexities, a collaborative approach is essential. Governments, tech companies, civil society, and academia can work together to devise regulations that address data privacy, platform accountability, and harmful content. By establishing baseline regulations, platforms can develop innovative compliance strategies while respecting diversity in global jurisdictions.
#
# Independent oversight bodies comprised of diverse stakeholders can monitor compliance and recommend adaptive regulatory adjustments. Such bodies ensure that regulations evolve with technological and societal changes, safeguarding public welfare without stifling innovation or free speech.
#
# Conclusion
#
# The regulation of social media platforms is a nuanced issue that demands careful balancing of benefits and challenges. Effective regulation should address misinformation, privacy violations, and harmful content while avoiding overreach and protecting fundamental freedoms. By adopting a balanced, collaborative approach, governments can establish effective regulatory mechanisms that protect public welfare and nurture the dynamic ecosystem of innovation and expression that social media offers. Through these efforts, we can foster a digital environment that benefits society while preserving individual liberties.

# %% [markdown]
# To better visualize the output of each step in the reflective writing workflow, we use a utility function called `show_output`. This function displays the results of each stage (drafting, reflection, and revision) in styled boxes with custom background and text colors, making it easier to compare and understand the progression of the essay.

# %%
from utils import show_output

essay_prompt = "Should social media platforms be regulated by the government?"

show_output("Step 1 – Draft", draft, background="#fff8dc", text_color="#333333")
show_output("Step 2 – Reflection", feedback, background="#e0f7fa", text_color="#222222")
show_output("Step 3 – Revision", revised, background="#f3e5f5", text_color="#222222")
# Out:
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #fff8dc;
#         color: #333333;
#     ">
#         <h3 style="margin-top: 0;">Step 1 – Draft</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Title: The Role of Government in Regulating Social Media Platforms
#
# Introduction
#
# The advent of social media has revolutionized how people communicate, share information, and engage with global communities. However, the rapid evolution of these platforms has also unleashed complex societal challenges, including the spread of misinformation, violations of privacy, and the impact on mental health. These challenges have sparked debates on whether social media platforms should be regulated by the government. This essay delves into the arguments for and against governmental regulation, ultimately advocating for a balanced approach that safeguards public interest while respecting freedom of expression.
#
# Arguments for Government Regulation
#
# 1. **Curbing Misinformation**: One of the most compelling arguments for government intervention is the need to control the spread of misinformation and fake news. Social media platforms have been used to disseminate false information rapidly, influencing public opinion and, at times, undermining democratic processes. Government regulation could mandate stricter content verification standards and hold platforms accountable for the spread of harmful misinformation.
#
# 2. **Protecting Privacy**: Social media platforms collect vast amounts of personal data, often with little transparency about how it is used. Government regulation could ensure robust data protection laws that safeguard users' privacy rights. By enforcing stringent data handling and privacy practices, governments can protect citizens from data breaches and misuse.
#
# 3. **Addressing Harmful Content**: The prevalence of hate speech, cyberbullying, and other harmful content on social media is another significant concern. Government regulation can compel platforms to implement better mechanisms for identifying and removing such material. This can create safer online environments and protect vulnerable populations from online abuse.
#
# 4. **Promoting Competition and Innovation**: The dominance of a few major social media companies has raised concerns about monopolistic practices. Government oversight can ensure fair competition and prevent these giants from stifling innovation or exploiting their market position at the expense of consumers and smaller businesses.
#
# Arguments Against Government Regulation
#
# 1. **Freedom of Expression**: One of the most significant concerns regarding government regulation is the potential threat to freedom of speech. Overregulation might lead to censorship, where legitimate expression is suppressed, stifling diverse opinions and infringing on the public's right to information.
#
# 2. **Innovation Stifling**: Heavy-handed regulation can inhibit technological innovation and adaptability. Social media platforms need the flexibility to evolve and improve their services. Overbearing regulatory frameworks might delay the introduction of new features and restrict creativity in addressing emerging challenges.
#
# 3. **Implementation Challenges**: Enforcing regulations consistently across diverse platforms presents substantial logistical challenges. Governments may struggle to keep pace with the technology's rapid evolution, resulting in outdated or irrelevant regulations that fail to address the actual issues.
#
# 4. **Global Reach and Jurisdiction Issues**: Social media platforms transcend national boundaries, leading to jurisdictional complexities. What one country deems necessary regulation may be viewed as overreach by another, complicating international compliance and cooperation efforts.
#
# Finding the Balance: A Collaborative Approach
#
# Given these contrasting perspectives, finding the right balance in regulating social media platforms is crucial. A collaborative approach, involving governments, tech companies, civil society, and academicians, can help achieve this balance. Governments can establish baseline regulations focusing on critical areas like data privacy, platform accountability, and harmful content, allowing platforms to devise innovative compliance methods.
#
# Additionally, independent oversight bodies comprising diverse stakeholders can be established to monitor compliance and recommend adjustments in regulations. Such bodies can ensure regulations evolve with technology and societal needs, creating adaptive frameworks that protect public interest without stifling innovation or free speech.
#
# Conclusion
#
# The regulation of social media platforms by the government is a multifaceted issue that requires careful consideration of both the benefits and potential drawbacks. While regulation is essential in addressing pressing concerns like misinformation, privacy erosion, and harmful content, it must be implemented thoughtfully to avoid overreach and infringement on fundamental freedoms. A balanced, collaborative approach can help establish effective regulatory mechanisms that protect public welfare while nurturing the vibrant ecosystem of innovation and expression that social media platforms offer.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #e0f7fa;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 2 – Reflection</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Your essay offers a clear and balanced exploration of government regulation of social media, yet a few adjustments could make your argument more compelling. Structurally, the “for” and “against” sections are well organized, but they read slightly like itemized lists; weaving in concrete examples or brief case studies—for instance, referencing a specific misinformation campaign or data-privacy breach—would ground your points and improve flow. Transitions between paragraphs could also be smoother to guide the reader more naturally from one idea to the next, especially into your conclusion, which currently restates earlier claims rather than synthesizing them. In terms of clarity, some sentences are densely packed with abstract concepts; simplifying phrasing and breaking complex thoughts into shorter statements would sharpen your message. Your writing style is formal and appropriate, yet it leans heavily on passive constructions—shifting to a more active voice and varying sentence rhythm would increase reader engagement. Finally, while you rightly highlight tensions between free speech and regulation, bolstering these claims with a few scholarly or legal citations would heighten the essay’s authority. With these refinements—more vivid examples, smoother transitions, clearer phrasing, and added evidence—your balanced approach will carry even greater persuasive weight.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #f3e5f5;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 3 – Revision</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Title: The Role of Government in Regulating Social Media Platforms
#
# Introduction
#
# Social media platforms have become integral to global communication, shaping how people interact, share information, and form communities. However, their rapid growth has also introduced significant challenges, such as misinformation, privacy violations, and impacts on mental health. These challenges necessitate a discussion on the role of government in regulating these platforms. This essay examines both sides of the argument and advocates for a balanced approach that safeguards public interest while upholding freedom of expression.
#
# Arguments for Government Regulation
#
# 1. **Curbing Misinformation**: Social media platforms have been breeding grounds for misinformation and fake news. For instance, during recent elections, false narratives spread rapidly, potentially influencing public opinion and jeopardizing democratic processes. Government intervention is crucial to enforce content verification standards and hold platforms accountable for the dissemination of harmful misinformation.
#
# 2. **Protecting Privacy**: Social media platforms often collect vast amounts of personal data without clear transparency, as seen in notable data breaches like the Cambridge Analytica scandal. To protect privacy rights, government regulations are necessary to ensure robust data protection laws and enforce stringent data handling practices.
#
# 3. **Addressing Harmful Content**: The spread of hate speech and cyberbullying is prevalent on social media. For example, incidents of online harassment have shown the need for better content moderation. Government regulation can require platforms to identify and remove harmful content, creating safer online spaces.
#
# 4. **Promoting Competition and Innovation**: The dominance of major players stifles competition and innovation. Past instances show how monopolistic practices can hinder smaller enterprises. Through oversight, governments can foster fair competition, ensuring that new players have the opportunity to innovate and thrive.
#
# Arguments Against Government Regulation
#
# 1. **Freedom of Expression**: Government regulation risks infringing on freedom of speech. Historical censorship attempts have raised concerns about overreach, where legitimate discourse might be stifled, limiting diverse viewpoints and the free flow of information.
#
# 2. **Innovation Stifling**: Strict regulations may impede the creative evolution of social media platforms. Overbearing rules could delay the introduction of new features, as platforms struggle to comply with complex regulatory frameworks.
#
# 3. **Implementation Challenges**: Governments face difficulties in enforcing regulations efficiently. Social media evolves rapidly, and regulators may struggle to keep pace, resulting in outdated rules that fail to address current issues.
#
# 4. **Global Reach and Jurisdiction Issues**: Social media's international scope complicates regulation. Conflicting national laws can lead to jurisdictional challenges, as seen in differing privacy laws across countries, complicating compliance for global platforms.
#
# Finding the Balance: A Collaborative Approach
#
# To navigate these complexities, a collaborative approach is essential. Governments, tech companies, civil society, and academia can work together to devise regulations that address data privacy, platform accountability, and harmful content. By establishing baseline regulations, platforms can develop innovative compliance strategies while respecting diversity in global jurisdictions.
#
# Independent oversight bodies comprised of diverse stakeholders can monitor compliance and recommend adaptive regulatory adjustments. Such bodies ensure that regulations evolve with technological and societal changes, safeguarding public welfare without stifling innovation or free speech.
#
# Conclusion
#
# The regulation of social media platforms is a nuanced issue that demands careful balancing of benefits and challenges. Effective regulation should address misinformation, privacy violations, and harmful content while avoiding overreach and protecting fundamental freedoms. By adopting a balanced, collaborative approach, governments can establish effective regulatory mechanisms that protect public welfare and nurture the dynamic ecosystem of innovation and expression that social media offers. Through these efforts, we can foster a digital environment that benefits society while preserving individual liberties.</pre>
#     </div>

# %% [markdown]
# ## Check grading feedback
#
# If you have collapsed the right panel to have more screen space for your code, as shown below:
#
# <img src="./images/collapsed.png" alt="Collapsed Image" width="800" height="400"/>
#
# You can click on the left-facing arrow button (highlighted in red) to view feedback for your submission after submitting it for grading. Once expanded, it should display like this:
#
# <img src="./images/expanded.png" alt="Expanded Image" width="800" height="400"/>
